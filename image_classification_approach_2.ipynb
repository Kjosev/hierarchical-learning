# %%
import numpy as np
import tensorflow as tf

from model import *
from dataset import *
# Out:
# C:\Users\kjosev\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# set up options

options = {}
options['margin'] = 50000
options['lrate'] = 0.05
options['dim'] = 250
options['epochs'] = 50
options['batch_size'] = 256
options['dataset'] = 'awa2'
options['num_base_classes'] = 50
options['abs'] = True

# %%
# fixing the seed
np.random.seed(12345)
tf.set_random_seed(12345)

# %%
# HYPERNYM PREDICTION DATA
hypernyms, name2index = load_hypernym_dataset(options['dataset'], 
                                              options['num_base_classes'])

options['num_all_classes'] = len(name2index)

# one hot encoding for each class with hierarchy 
hypernyms_per_class = get_hypernyms_per_class(
        hypernyms, options['num_base_classes'], options['num_all_classes'])

print('Number of base and parent classes:', len(name2index))
print('Number of hypernym pairs:', len(hypernyms))
# Out:
# Number of base and parent classes: 106
# Number of hypernym pairs: 1332

# %%
# IMAGE CLASSIFICATION DATA
X, labels = load_data()
X_train, X_val, X_test, y_train, y_val, y_test = split_data(X, labels)

print('Dataset size:', X.shape)
print('Train size:', len(X_train))
print('Validation size:', len(X_val))
print('Test size:', len(X_test))
# Out:
# Dataset size: (37322, 4096)
# Train size: 29857
# Validation size: 3733
# Test size: 3732

# %%
# Setting up our Adam optimizer 
optimizer = tf.train.AdamOptimizer(learning_rate=options['lrate'])

# %%
# HYPERNYM PREDICTION MODEL
pos_ch = tf.placeholder(tf.int64, shape=[None])
pos_pr = tf.placeholder(tf.int64, shape=[None])
neg_ch = tf.placeholder(tf.int64, shape=[None])
neg_pr = tf.placeholder(tf.int64, shape=[None])

hypernym_model = get_hypernym_model(pos_ch, pos_pr, neg_ch, neg_pr, options)

(h_acc, pos_acc, neg_acc), _, h_loss = hypernym_model

# hypernym prediction model only updates W_c (class) weights   
h_train_op = optimizer.minimize(h_loss)

# %%
# IMAGE CLASSIFICATION MODEL
im = tf.placeholder(tf.float64, shape=[None, X.shape[1]])
y = tf.placeholder(tf.int32, shape=[None])

classification_model = get_classification_model(im, y, options)

cls_acc, _, cls_loss, cls_pred = classification_model

# top 10 predictions
flat_hit_pred = get_prediction(im, 10, options) 

# get errors for all classes
cls_all_errors = get_classification_errors_all_classes(im, options) 

# image classification model updates W_i (image) and W_c (class) weights    
cls_train_op = optimizer.minimize(cls_loss)

# %%
# define our tf session
sess = tf.Session()


# initialize weights
init = tf.global_variables_initializer()
sess.run(init)
sess.run(tf.local_variables_initializer())

# %%
# Train the hypernym prediction model

hp_steps = 0
ic_steps = 0

h_p_acc_list = []
h_n_acc_list = []
h_acc_list = []
h_loss_list = []

ic_loss_list = []
ic_train_acc_list = []
ic_val_acc_list = []

for epoch in range(1, options['epochs']):
    print("Epoch:", epoch)
    
    print("========== HYPERNYM PREDICTION ==========")
    
    h_p_acc_avg = 0
    h_n_acc_avg = 0
    h_acc_avg = 0
    h_loss_avg = 0

    for batch_idxs in get_batch_idxs(len(hypernyms), options['batch_size']):
        positive = hypernyms[batch_idxs]
        negative = generate_negative_hypernyms(len(positive), options['num_all_classes'])

        #feed to training and get results
        _, curr_loss, curr_p_acc, curr_n_acc, curr_acc = sess.run(
            [h_train_op, h_loss, pos_acc, neg_acc, h_acc], feed_dict= {
                pos_ch: positive[:,0], # children
                pos_pr: positive[:,1], # parents
                neg_ch: negative[:,0],
                neg_pr: negative[:,1]
            })
    
        # update average loss and accuracy
        h_p_acc_avg += curr_p_acc * len(batch_idxs) / float(len(hypernyms))
        h_n_acc_avg += curr_n_acc * len(batch_idxs) / float(len(hypernyms))
        h_acc_avg += curr_acc * len(batch_idxs) / float(len(hypernyms))
        h_loss_avg += curr_loss * len(batch_idxs) / float(len(hypernyms))

        if hp_steps % 10 == 0:
            print("Steps: %05d Currernt loss %f " % (hp_steps, curr_loss))

        hp_steps += 1

    print("Train Positive Accuracy: ", h_p_acc_avg )
    print("Train Negative Accuracy: ", h_n_acc_avg)
    print("Train Accuracy: ", h_acc_avg)
    
    
    h_p_acc_list.append(h_p_acc_avg)
    h_n_acc_list.append(h_n_acc_avg)
    h_acc_list.append(h_acc_avg)
    h_loss_list.append(h_loss_avg)
    
    print("========== IMAGE CLASSIFICATION ==========")
    
    # variables to keep track of our average loss and accuracy
    ic_loss_avg = 0
    train_acc_avg = 0

    # run batched training
    for batch_idxs in get_batch_idxs(len(X_train), options['batch_size']):
        
        _, accur, curr_cls_loss = sess.run(
            [cls_train_op, cls_acc, cls_loss], feed_dict= {
                im: X_train[batch_idxs], 
                y: y_train[batch_idxs]
            })
        
        ic_steps += 1
        
        # update average loss and accuracy
        ic_loss_avg += curr_cls_loss * len(batch_idxs) / float(len(X_train))
        train_acc_avg += accur * len(batch_idxs) / float(len(X_train))

        if ic_steps % 10 == 0:
            print("Steps: %05d Accuracy: %f" % (
                ic_steps, accur))

    print()
    print("Train Accuracy: %f Loss: %f\n" % (
            train_acc_avg, 
            ic_loss_avg
        )
    )
    
    ic_loss_list.append(ic_loss_avg)
    ic_train_acc_list.append(train_acc_avg)
    
    # variables to keep track of our average val loss and accuracy
    val_acc_avg = 0
    
    # get validation accuracy in batches
    for batch_idxs in get_batch_idxs(len(X_val), options['batch_size']):
        [curr_val_accur] = sess.run(
            [cls_acc], feed_dict={ 
                im: X_val[batch_idxs], 
                y: y_val[batch_idxs]
            }
        )

        val_acc_avg += curr_val_accur * len(batch_idxs) / float(len(X_val))

    print("\nValidation Accuracy: %f \n" % (val_acc_avg))
    
    ic_val_acc_list.append(val_acc_avg)
# Out:
# Epoch: 1
# ========== HYPERNYM PREDICTION ==========
# Steps: 00000 Currernt loss 12799999.041901
# Train Positive Accuracy:  1.0
# Train Negative Accuracy:  0.0
# Train Accuracy:  0.5
# ========== IMAGE CLASSIFICATION ==========
# Steps: 00010 Accuracy: 0.039062
# Steps: 00020 Accuracy: 0.156250
# Steps: 00030 Accuracy: 0.132812
# Steps: 00040 Accuracy: 0.144531
# Steps: 00050 Accuracy: 0.164062
# Steps: 00060 Accuracy: 0.148438
# Steps: 00070 Accuracy: 0.187500
# Steps: 00080 Accuracy: 0.238281
# Steps: 00090 Accuracy: 0.214844
# Steps: 00100 Accuracy: 0.199219
# Steps: 00110 Accuracy: 0.250000
#
# Train Accuracy: 0.160733 Loss: 575956891.703763
#
#
# Validation Accuracy: 0.270828
#
# Epoch: 2
# ========== HYPERNYM PREDICTION ==========
# Steps: 00010 Currernt loss 12025010.065472
# Train Positive Accuracy:  1.0
# Train Negative Accuracy:  0.0
# Train Accuracy:  0.5
# ========== IMAGE CLASSIFICATION ==========
# Steps: 00120 Accuracy: 0.273438
# Steps: 00130 Accuracy: 0.289062
# Steps: 00140 Accuracy: 0.308594
# Steps: 00150 Accuracy: 0.367188
# Steps: 00160 Accuracy: 0.343750
# Steps: 00170 Accuracy: 0.375000
# Steps: 00180 Accuracy: 0.386719
# Steps: 00190 Accuracy: 0.414062
# Steps: 00200 Accuracy: 0.402344
# Steps: 00210 Accuracy: 0.429688
# Steps: 00220 Accuracy: 0.519531
# Steps: 00230 Accuracy: 0.460938
#
# Train Accuracy: 0.380748 Loss: 341946173.856294
#
#
# Validation Accuracy: 0.491830
#
# Epoch: 3
# ========== HYPERNYM PREDICTION ==========
# Train Positive Accuracy:  1.0
# Train Negative Accuracy:  0.018018018018018018
# Train Accuracy:  0.5090090090090089
# ========== IMAGE CLASSIFICATION ==========
# Steps: 00240 Accuracy: 0.503906
# Steps: 00250 Accuracy: 0.480469
# Steps: 00260 Accuracy: 0.464844
# Steps: 00270 Accuracy: 0.500000
# Steps: 00280 Accuracy: 0.578125
# Steps: 00290 Accuracy: 0.589844
# Steps: 00300 Accuracy: 0.554688
# Steps: 00310 Accuracy: 0.609375
# Steps: 00320 Accuracy: 0.628906
# Steps: 00330 Accuracy: 0.632812
# Steps: 00340 Accuracy: 0.648438
# Steps: 00350 Accuracy: 0.710938
#
# Train Accuracy: 0.571089 Loss: 166266909.974987
#
#
# Validation Accuracy: 0.684168
#
# Epoch: 4
# ========== HYPERNYM PREDICTION ==========
# Steps: 00020 Currernt loss 9739933.469471
# Train Positive Accuracy:  1.0
# Train Negative Accuracy:  0.02177177177177177
# Train Accuracy:  0.5108858858858859
# ========== IMAGE CLASSIFICATION ==========
# Steps: 00360 Accuracy: 0.687500
# Steps: 00370 Accuracy: 0.703125
# Steps: 00380 Accuracy: 0.742188
# Steps: 00390 Accuracy: 0.699219
# Steps: 00400 Accuracy: 0.785156
# Steps: 00410 Accuracy: 0.746094
# Steps: 00420 Accuracy: 0.667969
# Steps: 00430 Accuracy: 0.742188
# Steps: 00440 Accuracy: 0.781250
# Steps: 00450 Accuracy: 0.734375
# Steps: 00460 Accuracy: 0.753906
#
# Train Accuracy: 0.727334 Loss: 81452229.608700
#
#
# Validation Accuracy: 0.757032
#
# Epoch: 5
# ========== HYPERNYM PREDICTION ==========
# Train Positive Accuracy:  1.0
# Train Negative Accuracy:  0.0855855855855856
# Train Accuracy:  0.5427927927927928
# ========== IMAGE CLASSIFICATION ==========
# Steps: 00470 Accuracy: 0.730469
# Steps: 00480 Accuracy: 0.796875
# Steps: 00490 Accuracy: 0.769531
# Steps: 00500 Accuracy: 0.789062
# Steps: 00510 Accuracy: 0.777344
# Steps: 00520 Accuracy: 0.824219
# Steps: 00530 Accuracy: 0.816406
# Steps: 00540 Accuracy: 0.792969
# Steps: 00550 Accuracy: 0.789062
# Steps: 00560 Accuracy: 0.800781
# Steps: 00570 Accuracy: 0.765625
# Steps: 00580 Accuracy: 0.792969
#
# Train Accuracy: 0.784037 Loss: 50049879.101082
#
#
# Validation Accuracy: 0.792124
#
# Epoch: 6
# ========== HYPERNYM PREDICTION ==========
# Steps: 00030 Currernt loss 7861548.917428
# Train Positive Accuracy:  1.0
# Train Negative Accuracy:  0.19444444444444445
# Train Accuracy:  0.5972222222222222
# ========== IMAGE CLASSIFICATION ==========
# Steps: 00590 Accuracy: 0.753906
# Steps: 00600 Accuracy: 0.781250
# Steps: 00610 Accuracy: 0.757812
# Steps: 00620 Accuracy: 0.808594
# Steps: 00630 Accuracy: 0.847656
# Steps: 00640 Accuracy: 0.828125
# Steps: 00650 Accuracy: 0.796875
# Steps: 00660 Accuracy: 0.851562
# Steps: 00670 Accuracy: 0.832031
# Steps: 00680 Accuracy: 0.785156
# Steps: 00690 Accuracy: 0.785156
# Steps: 00700 Accuracy: 0.812500
#
# Train Accuracy: 0.803430 Loss: 35548808.029558
#
#
# Validation Accuracy: 0.818912
#
# Epoch: 7
# ========== HYPERNYM PREDICTION ==========
# Steps: 00040 Currernt loss 7328797.098217
# Train Positive Accuracy:  1.0
# Train Negative Accuracy:  0.25225225225225223
# Train Accuracy:  0.6261261261261261
# ========== IMAGE CLASSIFICATION ==========
# Steps: 00710 Accuracy: 0.808594
# Steps: 00720 Accuracy: 0.800781
# Steps: 00730 Accuracy: 0.800781
# Steps: 00740 Accuracy: 0.832031
# Steps: 00750 Accuracy: 0.839844
# Steps: 00760 Accuracy: 0.832031
# Steps: 00770 Accuracy: 0.867188
# Steps: 00780 Accuracy: 0.789062
# Steps: 00790 Accuracy: 0.816406
# Steps: 00800 Accuracy: 0.843750
# Steps: 00810 Accuracy: 0.804688
#
# Train Accuracy: 0.823693 Loss: 27500520.263044
#
#
# Validation Accuracy: 0.826681
#
# Epoch: 8
# ========== HYPERNYM PREDICTION ==========
# Train Positive Accuracy:  1.0
# Train Negative Accuracy:  0.283033033033033
# Train Accuracy:  0.6415165165165165
# ========== IMAGE CLASSIFICATION ==========
# Steps: 00820 Accuracy: 0.843750
# Steps: 00830 Accuracy: 0.839844
# Steps: 00840 Accuracy: 0.789062
# Steps: 00850 Accuracy: 0.832031
# Steps: 00860 Accuracy: 0.828125
# Steps: 00870 Accuracy: 0.906250
# Steps: 00880 Accuracy: 0.867188
# Steps: 00890 Accuracy: 0.824219
# Steps: 00900 Accuracy: 0.820312
# Steps: 00910 Accuracy: 0.851562
# Steps: 00920 Accuracy: 0.843750
# Steps: 00930 Accuracy: 0.847656
#
# Train Accuracy: 0.832602 Loss: 22575909.606301
#
#
# Validation Accuracy: 0.833914
#
# Epoch: 9
# ========== HYPERNYM PREDICTION ==========
# Steps: 00050 Currernt loss 7325643.666108
# Train Positive Accuracy:  1.0
# Train Negative Accuracy:  0.3468468468468468
# Train Accuracy:  0.6734234234234234
# ========== IMAGE CLASSIFICATION ==========
# Steps: 00940 Accuracy: 0.894531
# Steps: 00950 Accuracy: 0.785156
# Steps: 00960 Accuracy: 0.835938
# Steps: 00970 Accuracy: 0.804688
# Steps: 00980 Accuracy: 0.824219
# Steps: 00990 Accuracy: 0.835938
# Steps: 01000 Accuracy: 0.843750
# Steps: 01010 Accuracy: 0.878906
# Steps: 01020 Accuracy: 0.804688
# Steps: 01030 Accuracy: 0.835938
# Steps: 01040 Accuracy: 0.855469
# Steps: 01050 Accuracy: 0.875000
#
# Train Accuracy: 0.847305 Loss: 19031950.362068
#
#
# Validation Accuracy: 0.850254
#
# Epoch: 10
# ========== HYPERNYM PREDICTION ==========
# Train Positive Accuracy:  1.0
# Train Negative Accuracy:  0.3948948948948949
# Train Accuracy:  0.6974474474474475
# ========== IMAGE CLASSIFICATION ==========
# Steps: 01060 Accuracy: 0.835938
# Steps: 01070 Accuracy: 0.867188
# Steps: 01080 Accuracy: 0.863281
# Steps: 01090 Accuracy: 0.863281
# Steps: 01100 Accuracy: 0.894531
# Steps: 01110 Accuracy: 0.828125
# Steps: 01120 Accuracy: 0.847656
# Steps: 01130 Accuracy: 0.906250
# Steps: 01140 Accuracy: 0.859375
# Steps: 01150 Accuracy: 0.882812
# Steps: 01160 Accuracy: 0.890625
# Steps: 01170 Accuracy: 0.826087
#
# Train Accuracy: 0.858827 Loss: 16297164.522629
#
#
# Validation Accuracy: 0.857219
#
# Epoch: 11
# ========== HYPERNYM PREDICTION ==========
# Steps: 00060 Currernt loss 6129138.938753
# Train Positive Accuracy:  1.0
# Train Negative Accuracy:  0.37762762762762764
# Train Accuracy:  0.6888138138138138
# ========== IMAGE CLASSIFICATION ==========
# Steps: 01180 Accuracy: 0.886719
# Steps: 01190 Accuracy: 0.859375
# Steps: 01200 Accuracy: 0.886719
# Steps: 01210 Accuracy: 0.914062
# Steps: 01220 Accuracy: 0.859375
# Steps: 01230 Accuracy: 0.839844
# Steps: 01240 Accuracy: 0.894531
# Steps: 01250 Accuracy: 0.828125
# Steps: 01260 Accuracy: 0.898438
# Steps: 01270 Accuracy: 0.875000
# Steps: 01280 Accuracy: 0.890625
#
# Train Accuracy: 0.870047 Loss: 14104674.322276
#
#
# Validation Accuracy: 0.865524
#
# Epoch: 12
# ========== HYPERNYM PREDICTION ==========
# Steps: 00070 Currernt loss 5912778.126729
# Train Positive Accuracy:  1.0
# Train Negative Accuracy:  0.41516516516516516
# Train Accuracy:  0.7075825825825826
# ========== IMAGE CLASSIFICATION ==========
# Steps: 01290 Accuracy: 0.882812
# Steps: 01300 Accuracy: 0.886719
# Steps: 01310 Accuracy: 0.875000
# Steps: 01320 Accuracy: 0.898438
# Steps: 01330 Accuracy: 0.941406
# Steps: 01340 Accuracy: 0.906250
# Steps: 01350 Accuracy: 0.882812
# Steps: 01360 Accuracy: 0.894531
# Steps: 01370 Accuracy: 0.851562
# Steps: 01380 Accuracy: 0.847656
# Steps: 01390 Accuracy: 0.898438
# Steps: 01400 Accuracy: 0.910156
#
# Train Accuracy: 0.880865 Loss: 12289871.865653
#
#
# Validation Accuracy: 0.868738
#
# Epoch: 13
# ========== HYPERNYM PREDICTION ==========
# Train Positive Accuracy:  0.9992492492492493
# Train Negative Accuracy:  0.4054054054054054
# Train Accuracy:  0.7023273273273273
# ========== IMAGE CLASSIFICATION ==========
# Steps: 01410 Accuracy: 0.871094
# Steps: 01420 Accuracy: 0.914062
# Steps: 01430 Accuracy: 0.875000
# Steps: 01440 Accuracy: 0.855469
# Steps: 01450 Accuracy: 0.886719
# Steps: 01460 Accuracy: 0.867188
# Steps: 01470 Accuracy: 0.851562
# Steps: 01480 Accuracy: 0.906250
# Steps: 01490 Accuracy: 0.890625
# Steps: 01500 Accuracy: 0.898438
# Steps: 01510 Accuracy: 0.875000
# Steps: 01520 Accuracy: 0.882812
#
# Train Accuracy: 0.886727 Loss: 10950646.529556
#
#
# Validation Accuracy: 0.871953
#
# Epoch: 14
# ========== HYPERNYM PREDICTION ==========
# Steps: 00080 Currernt loss 4930178.695811
# Train Positive Accuracy:  0.9992492492492493
# Train Negative Accuracy:  0.45345345345345345
# Train Accuracy:  0.7263513513513513
# ========== IMAGE CLASSIFICATION ==========
# Steps: 01530 Accuracy: 0.855469
# Steps: 01540 Accuracy: 0.914062
# Steps: 01550 Accuracy: 0.890625
# Steps: 01560 Accuracy: 0.898438
# Steps: 01570 Accuracy: 0.890625
# Steps: 01580 Accuracy: 0.902344
# Steps: 01590 Accuracy: 0.894531
# Steps: 01600 Accuracy: 0.875000
# Steps: 01610 Accuracy: 0.906250
# Steps: 01620 Accuracy: 0.894531
# Steps: 01630 Accuracy: 0.902344
#
# Train Accuracy: 0.891717 Loss: 9874956.466004
#
#
# Validation Accuracy: 0.874096
#
# Epoch: 15
# ========== HYPERNYM PREDICTION ==========
# Train Positive Accuracy:  0.9992492492492492
# Train Negative Accuracy:  0.4654654654654654
# Train Accuracy:  0.7323573573573574
# ========== IMAGE CLASSIFICATION ==========
# Steps: 01640 Accuracy: 0.875000
# Steps: 01650 Accuracy: 0.906250
# Steps: 01660 Accuracy: 0.917969
# Steps: 01670 Accuracy: 0.882812
# Steps: 01680 Accuracy: 0.859375
# Steps: 01690 Accuracy: 0.917969
# Steps: 01700 Accuracy: 0.914062
# Steps: 01710 Accuracy: 0.910156
# Steps: 01720 Accuracy: 0.910156
# Steps: 01730 Accuracy: 0.890625
# Steps: 01740 Accuracy: 0.906250
# Steps: 01750 Accuracy: 0.886719
#
# Train Accuracy: 0.896674 Loss: 8769756.229106
#
#
# Validation Accuracy: 0.876775
#
# Epoch: 16
# ========== HYPERNYM PREDICTION ==========
# Steps: 00090 Currernt loss 5133288.284614
# Train Positive Accuracy:  0.9992492492492492
# Train Negative Accuracy:  0.493993993993994
# Train Accuracy:  0.7466216216216216
# ========== IMAGE CLASSIFICATION ==========
# Steps: 01760 Accuracy: 0.871094
# Steps: 01770 Accuracy: 0.886719
# Steps: 01780 Accuracy: 0.910156
# Steps: 01790 Accuracy: 0.855469
# Steps: 01800 Accuracy: 0.882812
# Steps: 01810 Accuracy: 0.933594
# Steps: 01820 Accuracy: 0.875000
# Steps: 01830 Accuracy: 0.941406
# Steps: 01840 Accuracy: 0.906250
# Steps: 01850 Accuracy: 0.882812
# Steps: 01860 Accuracy: 0.863281
# Steps: 01870 Accuracy: 0.921875
#
# Train Accuracy: 0.901866 Loss: 7908837.161335
#
#
# Validation Accuracy: 0.881864
#
# Epoch: 17
# ========== HYPERNYM PREDICTION ==========
# Steps: 00100 Currernt loss 4491554.867156
# Train Positive Accuracy:  0.9992492492492492
# Train Negative Accuracy:  0.5000000000000001
# Train Accuracy:  0.7496246246246245
# ========== IMAGE CLASSIFICATION ==========
# Steps: 01880 Accuracy: 0.914062
# Steps: 01890 Accuracy: 0.953125
# Steps: 01900 Accuracy: 0.875000
# Steps: 01910 Accuracy: 0.914062
# Steps: 01920 Accuracy: 0.902344
# Steps: 01930 Accuracy: 0.906250
# Steps: 01940 Accuracy: 0.925781
# Steps: 01950 Accuracy: 0.925781
# Steps: 01960 Accuracy: 0.945312
# Steps: 01970 Accuracy: 0.890625
# Steps: 01980 Accuracy: 0.890625
#
# Train Accuracy: 0.906890 Loss: 7157657.712635
#
#
# Validation Accuracy: 0.883472
#
# Epoch: 18
# ========== HYPERNYM PREDICTION ==========
# Train Positive Accuracy:  0.9977477477477478
# Train Negative Accuracy:  0.5015015015015014
# Train Accuracy:  0.7496246246246246
# ========== IMAGE CLASSIFICATION ==========
# Steps: 01990 Accuracy: 0.917969
# Steps: 02000 Accuracy: 0.910156
# Steps: 02010 Accuracy: 0.914062
# Steps: 02020 Accuracy: 0.902344
# Steps: 02030 Accuracy: 0.898438
# Steps: 02040 Accuracy: 0.929688
# Steps: 02050 Accuracy: 0.929688
# Steps: 02060 Accuracy: 0.925781
# Steps: 02070 Accuracy: 0.925781
# Steps: 02080 Accuracy: 0.902344
# Steps: 02090 Accuracy: 0.921875
# Steps: 02100 Accuracy: 0.882812
#
# Train Accuracy: 0.911076 Loss: 6439202.233775
#
#
# Validation Accuracy: 0.886686
#
# Epoch: 19
# ========== HYPERNYM PREDICTION ==========
# Steps: 00110 Currernt loss 4347415.534499
# Train Positive Accuracy:  0.9977477477477478
# Train Negative Accuracy:  0.524024024024024
# Train Accuracy:  0.760885885885886
# ========== IMAGE CLASSIFICATION ==========
# Steps: 02110 Accuracy: 0.914062
# Steps: 02120 Accuracy: 0.917969
# Steps: 02130 Accuracy: 0.910156
# Steps: 02140 Accuracy: 0.925781
# Steps: 02150 Accuracy: 0.933594
# Steps: 02160 Accuracy: 0.921875
# Steps: 02170 Accuracy: 0.925781
# Steps: 02180 Accuracy: 0.937500
# Steps: 02190 Accuracy: 0.921875
# Steps: 02200 Accuracy: 0.890625
# Steps: 02210 Accuracy: 0.910156
# Steps: 02220 Accuracy: 0.914062
#
# Train Accuracy: 0.914526 Loss: 5936262.689311
#
#
# Validation Accuracy: 0.885079
#
# Epoch: 20
# ========== HYPERNYM PREDICTION ==========
# Train Positive Accuracy:  0.996996996996997
# Train Negative Accuracy:  0.5548048048048048
# Train Accuracy:  0.7759009009009008
# ========== IMAGE CLASSIFICATION ==========
# Steps: 02230 Accuracy: 0.902344
# Steps: 02240 Accuracy: 0.949219
# Steps: 02250 Accuracy: 0.914062
# Steps: 02260 Accuracy: 0.902344
# Steps: 02270 Accuracy: 0.937500
# Steps: 02280 Accuracy: 0.937500
# Steps: 02290 Accuracy: 0.914062
# Steps: 02300 Accuracy: 0.953125
# Steps: 02310 Accuracy: 0.921875
# Steps: 02320 Accuracy: 0.929688
# Steps: 02330 Accuracy: 0.894531
# Steps: 02340 Accuracy: 0.906832
#
# Train Accuracy: 0.920488 Loss: 5427812.808556
#
#
# Validation Accuracy: 0.888829
#
# Epoch: 21
# ========== HYPERNYM PREDICTION ==========
# Steps: 00120 Currernt loss 3642314.627601
# Train Positive Accuracy:  0.9962462462462461
# Train Negative Accuracy:  0.566066066066066
# Train Accuracy:  0.7811561561561562
# ========== IMAGE CLASSIFICATION ==========
# Steps: 02350 Accuracy: 0.917969
# Steps: 02360 Accuracy: 0.945312
# Steps: 02370 Accuracy: 0.917969
# Steps: 02380 Accuracy: 0.929688
# Steps: 02390 Accuracy: 0.933594
# Steps: 02400 Accuracy: 0.921875
# Steps: 02410 Accuracy: 0.933594
# Steps: 02420 Accuracy: 0.910156
# Steps: 02430 Accuracy: 0.929688
# Steps: 02440 Accuracy: 0.929688
# Steps: 02450 Accuracy: 0.917969
#
# Train Accuracy: 0.925780 Loss: 4907228.914023
#
#
# Validation Accuracy: 0.890972
#
# Epoch: 22
# ========== HYPERNYM PREDICTION ==========
# Steps: 00130 Currernt loss 3902771.120826
# Train Positive Accuracy:  0.9954954954954954
# Train Negative Accuracy:  0.563063063063063
# Train Accuracy:  0.7792792792792793
# ========== IMAGE CLASSIFICATION ==========
# Steps: 02460 Accuracy: 0.921875
# Steps: 02470 Accuracy: 0.921875
# Steps: 02480 Accuracy: 0.917969
# Steps: 02490 Accuracy: 0.933594
# Steps: 02500 Accuracy: 0.914062
# Steps: 02510 Accuracy: 0.914062
# Steps: 02520 Accuracy: 0.917969
# Steps: 02530 Accuracy: 0.914062
# Steps: 02540 Accuracy: 0.917969
# Steps: 02550 Accuracy: 0.933594
# Steps: 02560 Accuracy: 0.933594
# Steps: 02570 Accuracy: 0.917969
#
# Train Accuracy: 0.929631 Loss: 4528255.314261
#
#
# Validation Accuracy: 0.892580
#
# Epoch: 23
# ========== HYPERNYM PREDICTION ==========
# Train Positive Accuracy:  0.9962462462462462
# Train Negative Accuracy:  0.6156156156156155
# Train Accuracy:  0.8059309309309308
# ========== IMAGE CLASSIFICATION ==========
# Steps: 02580 Accuracy: 0.937500
# Steps: 02590 Accuracy: 0.914062
# Steps: 02600 Accuracy: 0.921875
# Steps: 02610 Accuracy: 0.953125
# Steps: 02620 Accuracy: 0.937500
# Steps: 02630 Accuracy: 0.933594
# Steps: 02640 Accuracy: 0.937500
# Steps: 02650 Accuracy: 0.949219
# Steps: 02660 Accuracy: 0.945312
# Steps: 02670 Accuracy: 0.921875
# Steps: 02680 Accuracy: 0.929688
# Steps: 02690 Accuracy: 0.925781
#
# Train Accuracy: 0.934119 Loss: 4119274.556861
#
#
# Validation Accuracy: 0.896866
#
# Epoch: 24
# ========== HYPERNYM PREDICTION ==========
# Steps: 00140 Currernt loss 3683441.715815
# Train Positive Accuracy:  0.9962462462462462
# Train Negative Accuracy:  0.6148648648648648
# Train Accuracy:  0.8055555555555556
# ========== IMAGE CLASSIFICATION ==========
# Steps: 02700 Accuracy: 0.925781
# Steps: 02710 Accuracy: 0.945312
# Steps: 02720 Accuracy: 0.953125
# Steps: 02730 Accuracy: 0.937500
# Steps: 02740 Accuracy: 0.929688
# Steps: 02750 Accuracy: 0.937500
# Steps: 02760 Accuracy: 0.929688
# Steps: 02770 Accuracy: 0.933594
# Steps: 02780 Accuracy: 0.941406
# Steps: 02790 Accuracy: 0.945312
# Steps: 02800 Accuracy: 0.937500
#
# Train Accuracy: 0.938239 Loss: 3790536.645112
#
#
# Validation Accuracy: 0.893651
#
# Epoch: 25
# ========== HYPERNYM PREDICTION ==========
# Train Positive Accuracy:  0.9962462462462462
# Train Negative Accuracy:  0.6298798798798799
# Train Accuracy:  0.8130630630630631
# ========== IMAGE CLASSIFICATION ==========
# Steps: 02810 Accuracy: 0.949219
# Steps: 02820 Accuracy: 0.917969
# Steps: 02830 Accuracy: 0.953125
# Steps: 02840 Accuracy: 0.941406
# Steps: 02850 Accuracy: 0.937500
# Steps: 02860 Accuracy: 0.902344
# Steps: 02870 Accuracy: 0.917969
# Steps: 02880 Accuracy: 0.925781
# Steps: 02890 Accuracy: 0.945312
# Steps: 02900 Accuracy: 0.941406
# Steps: 02910 Accuracy: 0.937500
# Steps: 02920 Accuracy: 0.953125
#
# Train Accuracy: 0.941756 Loss: 3516729.463838
#
#
# Validation Accuracy: 0.894455
#
# Epoch: 26
# ========== HYPERNYM PREDICTION ==========
# Steps: 00150 Currernt loss 3124743.568317
# Train Positive Accuracy:  0.9962462462462461
# Train Negative Accuracy:  0.6268768768768768
# Train Accuracy:  0.8115615615615617
# ========== IMAGE CLASSIFICATION ==========
# Steps: 02930 Accuracy: 0.945312
# Steps: 02940 Accuracy: 0.941406
# Steps: 02950 Accuracy: 0.937500
# Steps: 02960 Accuracy: 0.929688
# Steps: 02970 Accuracy: 0.933594
# Steps: 02980 Accuracy: 0.957031
# Steps: 02990 Accuracy: 0.964844
# Steps: 03000 Accuracy: 0.937500
# Steps: 03010 Accuracy: 0.929688
# Steps: 03020 Accuracy: 0.925781
# Steps: 03030 Accuracy: 0.933594
# Steps: 03040 Accuracy: 0.976562
#
# Train Accuracy: 0.944033 Loss: 3266502.809790
#
#
# Validation Accuracy: 0.892848
#
# Epoch: 27
# ========== HYPERNYM PREDICTION ==========
# Steps: 00160 Currernt loss 2733171.112232
# Train Positive Accuracy:  0.9962462462462461
# Train Negative Accuracy:  0.6621621621621622
# Train Accuracy:  0.8292042042042042
# ========== IMAGE CLASSIFICATION ==========
# Steps: 03050 Accuracy: 0.949219
# Steps: 03060 Accuracy: 0.964844
# Steps: 03070 Accuracy: 0.941406
# Steps: 03080 Accuracy: 0.960938
# Steps: 03090 Accuracy: 0.949219
# Steps: 03100 Accuracy: 0.953125
# Steps: 03110 Accuracy: 0.953125
# Steps: 03120 Accuracy: 0.957031
# Steps: 03130 Accuracy: 0.953125
# Steps: 03140 Accuracy: 0.953125
# Steps: 03150 Accuracy: 0.953125
#
# Train Accuracy: 0.947014 Loss: 3005549.807964
#
#
# Validation Accuracy: 0.893115
#
# Epoch: 28
# ========== HYPERNYM PREDICTION ==========
# Train Positive Accuracy:  0.9962462462462462
# Train Negative Accuracy:  0.6749249249249248
# Train Accuracy:  0.8355855855855855
# ========== IMAGE CLASSIFICATION ==========
# Steps: 03160 Accuracy: 0.949219
# Steps: 03170 Accuracy: 0.964844
# Steps: 03180 Accuracy: 0.949219
# Steps: 03190 Accuracy: 0.949219
# Steps: 03200 Accuracy: 0.953125
# Steps: 03210 Accuracy: 0.960938
# Steps: 03220 Accuracy: 0.949219
# Steps: 03230 Accuracy: 0.937500
# Steps: 03240 Accuracy: 0.941406
# Steps: 03250 Accuracy: 0.929688
# Steps: 03260 Accuracy: 0.937500
# Steps: 03270 Accuracy: 0.941406
#
# Train Accuracy: 0.949828 Loss: 2800579.813945
#
#
# Validation Accuracy: 0.897669
#
# Epoch: 29
# ========== HYPERNYM PREDICTION ==========
# Steps: 00170 Currernt loss 2703298.418393
# Train Positive Accuracy:  0.9962462462462462
# Train Negative Accuracy:  0.6809309309309309
# Train Accuracy:  0.8385885885885886
# ========== IMAGE CLASSIFICATION ==========
# Steps: 03280 Accuracy: 0.949219
# Steps: 03290 Accuracy: 0.941406
# Steps: 03300 Accuracy: 0.964844
# Steps: 03310 Accuracy: 0.949219
# Steps: 03320 Accuracy: 0.960938
# Steps: 03330 Accuracy: 0.945312
# Steps: 03340 Accuracy: 0.949219
# Steps: 03350 Accuracy: 0.925781
# Steps: 03360 Accuracy: 0.976562
# Steps: 03370 Accuracy: 0.937500
# Steps: 03380 Accuracy: 0.980469
# Steps: 03390 Accuracy: 0.945312
#
# Train Accuracy: 0.951636 Loss: 2579930.014559
#
#
# Validation Accuracy: 0.900616
#
# Epoch: 30
# ========== HYPERNYM PREDICTION ==========
# Train Positive Accuracy:  0.9962462462462464
# Train Negative Accuracy:  0.6861861861861862
# Train Accuracy:  0.8412162162162161
# ========== IMAGE CLASSIFICATION ==========
# Steps: 03400 Accuracy: 0.933594
# Steps: 03410 Accuracy: 0.968750
# Steps: 03420 Accuracy: 0.960938
# Steps: 03430 Accuracy: 0.933594
# Steps: 03440 Accuracy: 0.953125
# Steps: 03450 Accuracy: 0.960938
# Steps: 03460 Accuracy: 0.937500
# Steps: 03470 Accuracy: 0.968750
# Steps: 03480 Accuracy: 0.957031
# Steps: 03490 Accuracy: 0.953125
# Steps: 03500 Accuracy: 0.960938
# Steps: 03510 Accuracy: 0.950311
#
# Train Accuracy: 0.953813 Loss: 2404233.062489
#
#
# Validation Accuracy: 0.900348
#
# Epoch: 31
# ========== HYPERNYM PREDICTION ==========
# Steps: 00180 Currernt loss 3289377.240528
# Train Positive Accuracy:  0.9977477477477477
# Train Negative Accuracy:  0.7132132132132132
# Train Accuracy:  0.8554804804804805
# ========== IMAGE CLASSIFICATION ==========
# Steps: 03520 Accuracy: 0.960938
# Steps: 03530 Accuracy: 0.980469
# Steps: 03540 Accuracy: 0.980469
# Steps: 03550 Accuracy: 0.953125
# Steps: 03560 Accuracy: 0.941406
# Steps: 03570 Accuracy: 0.929688
# Steps: 03580 Accuracy: 0.953125
# Steps: 03590 Accuracy: 0.925781
# Steps: 03600 Accuracy: 0.937500
# Steps: 03610 Accuracy: 0.976562
# Steps: 03620 Accuracy: 0.957031
#
# Train Accuracy: 0.956258 Loss: 2225700.180836
#
#
# Validation Accuracy: 0.896062
#
# Epoch: 32
# ========== HYPERNYM PREDICTION ==========
# Steps: 00190 Currernt loss 2960878.053150
# Train Positive Accuracy:  0.9977477477477478
# Train Negative Accuracy:  0.7079579579579579
# Train Accuracy:  0.8528528528528528
# ========== IMAGE CLASSIFICATION ==========
# Steps: 03630 Accuracy: 0.957031
# Steps: 03640 Accuracy: 0.968750
# Steps: 03650 Accuracy: 0.957031
# Steps: 03660 Accuracy: 0.964844
# Steps: 03670 Accuracy: 0.953125
# Steps: 03680 Accuracy: 0.945312
# Steps: 03690 Accuracy: 0.929688
# Steps: 03700 Accuracy: 0.929688
# Steps: 03710 Accuracy: 0.945312
# Steps: 03720 Accuracy: 0.941406
# Steps: 03730 Accuracy: 0.953125
# Steps: 03740 Accuracy: 0.937500
#
# Train Accuracy: 0.958402 Loss: 2101740.569497
#
#
# Validation Accuracy: 0.900080
#
# Epoch: 33
# ========== HYPERNYM PREDICTION ==========
# Train Positive Accuracy:  0.9977477477477477
# Train Negative Accuracy:  0.7327327327327328
# Train Accuracy:  0.8652402402402403
# ========== IMAGE CLASSIFICATION ==========
# Steps: 03750 Accuracy: 0.964844
# Steps: 03760 Accuracy: 0.968750
# Steps: 03770 Accuracy: 0.945312
# Steps: 03780 Accuracy: 0.972656
# Steps: 03790 Accuracy: 0.964844
# Steps: 03800 Accuracy: 0.960938
# Steps: 03810 Accuracy: 0.960938
# Steps: 03820 Accuracy: 0.960938
# Steps: 03830 Accuracy: 0.949219
# Steps: 03840 Accuracy: 0.964844
# Steps: 03850 Accuracy: 0.941406
# Steps: 03860 Accuracy: 0.957031
#
# Train Accuracy: 0.960646 Loss: 1985587.184876
#
#
# Validation Accuracy: 0.894991
#
# Epoch: 34
# ========== HYPERNYM PREDICTION ==========
# Steps: 00200 Currernt loss 2581792.497238
# Train Positive Accuracy:  0.9977477477477475
# Train Negative Accuracy:  0.7379879879879879
# Train Accuracy:  0.867867867867868
# ========== IMAGE CLASSIFICATION ==========
# Steps: 03870 Accuracy: 0.976562
# Steps: 03880 Accuracy: 0.945312
# Steps: 03890 Accuracy: 0.957031
# Steps: 03900 Accuracy: 0.957031
# Steps: 03910 Accuracy: 0.964844
# Steps: 03920 Accuracy: 0.972656
# Steps: 03930 Accuracy: 0.964844
# Steps: 03940 Accuracy: 0.964844
# Steps: 03950 Accuracy: 0.968750
# Steps: 03960 Accuracy: 0.957031
# Steps: 03970 Accuracy: 0.941406
#
# Train Accuracy: 0.962253 Loss: 1890014.068317
#
#
# Validation Accuracy: 0.899812
#
# Epoch: 35
# ========== HYPERNYM PREDICTION ==========
# Train Positive Accuracy:  0.9977477477477477
# Train Negative Accuracy:  0.7597597597597597
# Train Accuracy:  0.8787537537537538
# ========== IMAGE CLASSIFICATION ==========
# Steps: 03980 Accuracy: 0.957031
# Steps: 03990 Accuracy: 0.976562
# Steps: 04000 Accuracy: 0.980469
# Steps: 04010 Accuracy: 0.968750
# Steps: 04020 Accuracy: 0.941406
# Steps: 04030 Accuracy: 0.964844
# Steps: 04040 Accuracy: 0.968750
# Steps: 04050 Accuracy: 0.980469
# Steps: 04060 Accuracy: 0.964844
# Steps: 04070 Accuracy: 0.960938
# Steps: 04080 Accuracy: 0.972656
# Steps: 04090 Accuracy: 0.937500
#
# Train Accuracy: 0.964430 Loss: 1747489.913214
#
#
# Validation Accuracy: 0.897402
#
# Epoch: 36
# ========== HYPERNYM PREDICTION ==========
# Steps: 00210 Currernt loss 2274200.497083
# Train Positive Accuracy:  0.9977477477477477
# Train Negative Accuracy:  0.753003003003003
# Train Accuracy:  0.8753753753753754
# ========== IMAGE CLASSIFICATION ==========
# Steps: 04100 Accuracy: 0.960938
# Steps: 04110 Accuracy: 0.972656
# Steps: 04120 Accuracy: 0.953125
# Steps: 04130 Accuracy: 0.957031
# Steps: 04140 Accuracy: 0.964844
# Steps: 04150 Accuracy: 0.980469
# Steps: 04160 Accuracy: 0.968750
# Steps: 04170 Accuracy: 0.957031
# Steps: 04180 Accuracy: 0.960938
# Steps: 04190 Accuracy: 0.941406
# Steps: 04200 Accuracy: 0.980469
# Steps: 04210 Accuracy: 0.980469
#
# Train Accuracy: 0.966574 Loss: 1672058.529666
#
#
# Validation Accuracy: 0.900080
#
# Epoch: 37
# ========== HYPERNYM PREDICTION ==========
# Steps: 00220 Currernt loss 2291488.633105
# Train Positive Accuracy:  0.9977477477477477
# Train Negative Accuracy:  0.7507507507507508
# Train Accuracy:  0.8742492492492492
# ========== IMAGE CLASSIFICATION ==========
# Steps: 04220 Accuracy: 0.964844
# Steps: 04230 Accuracy: 0.972656
# Steps: 04240 Accuracy: 0.972656
# Steps: 04250 Accuracy: 0.976562
# Steps: 04260 Accuracy: 0.945312
# Steps: 04270 Accuracy: 0.964844
# Steps: 04280 Accuracy: 0.980469
# Steps: 04290 Accuracy: 0.976562
# Steps: 04300 Accuracy: 0.953125
# Steps: 04310 Accuracy: 0.964844
# Steps: 04320 Accuracy: 0.960938
#
# Train Accuracy: 0.967076 Loss: 1601195.451527
#
#
# Validation Accuracy: 0.896866
#
# Epoch: 38
# ========== HYPERNYM PREDICTION ==========
# Train Positive Accuracy:  0.9977477477477478
# Train Negative Accuracy:  0.7770270270270271
# Train Accuracy:  0.8873873873873873
# ========== IMAGE CLASSIFICATION ==========
# Steps: 04330 Accuracy: 0.949219
# Steps: 04340 Accuracy: 0.972656
# Steps: 04350 Accuracy: 0.972656
# Steps: 04360 Accuracy: 0.976562
# Steps: 04370 Accuracy: 0.957031
# Steps: 04380 Accuracy: 0.976562
# Steps: 04390 Accuracy: 0.980469
# Steps: 04400 Accuracy: 0.968750
# Steps: 04410 Accuracy: 0.957031
# Steps: 04420 Accuracy: 0.968750
# Steps: 04430 Accuracy: 0.953125
# Steps: 04440 Accuracy: 0.972656
#
# Train Accuracy: 0.967780 Loss: 1528640.670528
#
#
# Validation Accuracy: 0.900080
#
# Epoch: 39
# ========== HYPERNYM PREDICTION ==========
# Steps: 00230 Currernt loss 2023332.455329
# Train Positive Accuracy:  0.9984984984984985
# Train Negative Accuracy:  0.7665165165165165
# Train Accuracy:  0.8825075075075075
# ========== IMAGE CLASSIFICATION ==========
# Steps: 04450 Accuracy: 0.976562
# Steps: 04460 Accuracy: 0.964844
# Steps: 04470 Accuracy: 0.972656
# Steps: 04480 Accuracy: 0.980469
# Steps: 04490 Accuracy: 0.953125
# Steps: 04500 Accuracy: 0.968750
# Steps: 04510 Accuracy: 0.960938
# Steps: 04520 Accuracy: 0.972656
# Steps: 04530 Accuracy: 0.968750
# Steps: 04540 Accuracy: 0.960938
# Steps: 04550 Accuracy: 0.960938
# Steps: 04560 Accuracy: 0.980469
#
# Train Accuracy: 0.969153 Loss: 1466749.122472
#
#
# Validation Accuracy: 0.896598
#
# Epoch: 40
# ========== HYPERNYM PREDICTION ==========
# Train Positive Accuracy:  0.9984984984984984
# Train Negative Accuracy:  0.7935435435435436
# Train Accuracy:  0.896021021021021
# ========== IMAGE CLASSIFICATION ==========
# Steps: 04570 Accuracy: 0.972656
# Steps: 04580 Accuracy: 0.988281
# Steps: 04590 Accuracy: 0.960938
# Steps: 04600 Accuracy: 0.960938
# Steps: 04610 Accuracy: 0.980469
# Steps: 04620 Accuracy: 0.976562
# Steps: 04630 Accuracy: 0.957031
# Steps: 04640 Accuracy: 0.957031
# Steps: 04650 Accuracy: 0.976562
# Steps: 04660 Accuracy: 0.980469
# Steps: 04670 Accuracy: 0.972656
# Steps: 04680 Accuracy: 0.950311
#
# Train Accuracy: 0.970191 Loss: 1381749.079172
#
#
# Validation Accuracy: 0.900080
#
# Epoch: 41
# ========== HYPERNYM PREDICTION ==========
# Steps: 00240 Currernt loss 2107958.217327
# Train Positive Accuracy:  0.9984984984984984
# Train Negative Accuracy:  0.801051051051051
# Train Accuracy:  0.8997747747747746
# ========== IMAGE CLASSIFICATION ==========
# Steps: 04690 Accuracy: 0.968750
# Steps: 04700 Accuracy: 0.972656
# Steps: 04710 Accuracy: 0.968750
# Steps: 04720 Accuracy: 0.980469
# Steps: 04730 Accuracy: 0.988281
# Steps: 04740 Accuracy: 0.976562
# Steps: 04750 Accuracy: 0.980469
# Steps: 04760 Accuracy: 0.968750
# Steps: 04770 Accuracy: 0.976562
# Steps: 04780 Accuracy: 0.980469
# Steps: 04790 Accuracy: 0.972656
#
# Train Accuracy: 0.971598 Loss: 1317986.305113
#
#
# Validation Accuracy: 0.897402
#
# Epoch: 42
# ========== HYPERNYM PREDICTION ==========
# Steps: 00250 Currernt loss 2704435.194683
# Train Positive Accuracy:  0.9984984984984985
# Train Negative Accuracy:  0.7837837837837839
# Train Accuracy:  0.8911411411411412
# ========== IMAGE CLASSIFICATION ==========
# Steps: 04800 Accuracy: 0.972656
# Steps: 04810 Accuracy: 0.980469
# Steps: 04820 Accuracy: 0.972656
# Steps: 04830 Accuracy: 0.988281
# Steps: 04840 Accuracy: 0.957031
# Steps: 04850 Accuracy: 0.976562
# Steps: 04860 Accuracy: 0.996094
# Steps: 04870 Accuracy: 0.984375
# Steps: 04880 Accuracy: 0.988281
# Steps: 04890 Accuracy: 0.957031
# Steps: 04900 Accuracy: 0.988281
# Steps: 04910 Accuracy: 0.949219
#
# Train Accuracy: 0.972402 Loss: 1274148.879651
#
#
# Validation Accuracy: 0.897937
#
# Epoch: 43
# ========== HYPERNYM PREDICTION ==========
# Train Positive Accuracy:  0.9984984984984984
# Train Negative Accuracy:  0.792042042042042
# Train Accuracy:  0.8952702702702703
# ========== IMAGE CLASSIFICATION ==========
# Steps: 04920 Accuracy: 0.964844
# Steps: 04930 Accuracy: 1.000000
# Steps: 04940 Accuracy: 0.960938
# Steps: 04950 Accuracy: 0.980469
# Steps: 04960 Accuracy: 0.937500
# Steps: 04970 Accuracy: 0.968750
# Steps: 04980 Accuracy: 0.972656
# Steps: 04990 Accuracy: 0.984375
# Steps: 05000 Accuracy: 0.968750
# Steps: 05010 Accuracy: 0.968750
# Steps: 05020 Accuracy: 0.968750
# Steps: 05030 Accuracy: 0.964844
#
# Train Accuracy: 0.973608 Loss: 1225976.065469
#
#
# Validation Accuracy: 0.895526
#
# Epoch: 44
# ========== HYPERNYM PREDICTION ==========
# Steps: 00260 Currernt loss 2472645.764093
# Train Positive Accuracy:  0.9992492492492492
# Train Negative Accuracy:  0.7845345345345346
# Train Accuracy:  0.8918918918918919
# ========== IMAGE CLASSIFICATION ==========
# Steps: 05040 Accuracy: 0.972656
# Steps: 05050 Accuracy: 0.976562
# Steps: 05060 Accuracy: 0.960938
# Steps: 05070 Accuracy: 0.976562
# Steps: 05080 Accuracy: 0.972656
# Steps: 05090 Accuracy: 0.984375
# Steps: 05100 Accuracy: 0.980469
# Steps: 05110 Accuracy: 0.957031
# Steps: 05120 Accuracy: 0.976562
# Steps: 05130 Accuracy: 0.968750
# Steps: 05140 Accuracy: 0.984375
#
# Train Accuracy: 0.975048 Loss: 1138630.827045
#
#
# Validation Accuracy: 0.895794
#
# Epoch: 45
# ========== HYPERNYM PREDICTION ==========
# Train Positive Accuracy:  0.9992492492492492
# Train Negative Accuracy:  0.8138138138138138
# Train Accuracy:  0.9065315315315314
# ========== IMAGE CLASSIFICATION ==========
# Steps: 05150 Accuracy: 0.980469
# Steps: 05160 Accuracy: 0.988281
# Steps: 05170 Accuracy: 0.976562
# Steps: 05180 Accuracy: 0.980469
# Steps: 05190 Accuracy: 0.980469
# Steps: 05200 Accuracy: 0.980469
# Steps: 05210 Accuracy: 0.960938
# Steps: 05220 Accuracy: 0.992188
# Steps: 05230 Accuracy: 0.960938
# Steps: 05240 Accuracy: 0.980469
# Steps: 05250 Accuracy: 0.988281
# Steps: 05260 Accuracy: 0.976562
#
# Train Accuracy: 0.975584 Loss: 1142756.335540
#
#
# Validation Accuracy: 0.896330
#
# Epoch: 46
# ========== HYPERNYM PREDICTION ==========
# Steps: 00270 Currernt loss 2616688.018896
# Train Positive Accuracy:  0.9992492492492492
# Train Negative Accuracy:  0.7627627627627629
# Train Accuracy:  0.8810060060060059
# ========== IMAGE CLASSIFICATION ==========
# Steps: 05270 Accuracy: 0.960938
# Steps: 05280 Accuracy: 0.960938
# Steps: 05290 Accuracy: 0.968750
# Steps: 05300 Accuracy: 0.976562
# Steps: 05310 Accuracy: 0.957031
# Steps: 05320 Accuracy: 0.980469
# Steps: 05330 Accuracy: 0.980469
# Steps: 05340 Accuracy: 0.976562
# Steps: 05350 Accuracy: 0.972656
# Steps: 05360 Accuracy: 0.984375
# Steps: 05370 Accuracy: 0.949219
# Steps: 05380 Accuracy: 0.964844
#
# Train Accuracy: 0.975718 Loss: 1141812.840912
#
#
# Validation Accuracy: 0.897402
#
# Epoch: 47
# ========== HYPERNYM PREDICTION ==========
# Steps: 00280 Currernt loss 2107542.058053
# Train Positive Accuracy:  0.9992492492492493
# Train Negative Accuracy:  0.795045045045045
# Train Accuracy:  0.8971471471471472
# ========== IMAGE CLASSIFICATION ==========
# Steps: 05390 Accuracy: 0.988281
# Steps: 05400 Accuracy: 0.972656
# Steps: 05410 Accuracy: 0.968750
# Steps: 05420 Accuracy: 0.968750
# Steps: 05430 Accuracy: 0.988281
# Steps: 05440 Accuracy: 0.968750
# Steps: 05450 Accuracy: 0.984375
# Steps: 05460 Accuracy: 0.972656
# Steps: 05470 Accuracy: 0.976562
# Steps: 05480 Accuracy: 0.972656
# Steps: 05490 Accuracy: 0.976562
#
# Train Accuracy: 0.976521 Loss: 1149447.822823
#
#
# Validation Accuracy: 0.903295
#
# Epoch: 48
# ========== HYPERNYM PREDICTION ==========
# Train Positive Accuracy:  0.9992492492492492
# Train Negative Accuracy:  0.792042042042042
# Train Accuracy:  0.8956456456456456
# ========== IMAGE CLASSIFICATION ==========
# Steps: 05500 Accuracy: 0.972656
# Steps: 05510 Accuracy: 0.976562
# Steps: 05520 Accuracy: 0.980469
# Steps: 05530 Accuracy: 0.976562
# Steps: 05540 Accuracy: 0.972656
# Steps: 05550 Accuracy: 0.980469
# Steps: 05560 Accuracy: 0.980469
# Steps: 05570 Accuracy: 0.972656
# Steps: 05580 Accuracy: 0.980469
# Steps: 05590 Accuracy: 0.988281
# Steps: 05600 Accuracy: 0.996094
# Steps: 05610 Accuracy: 0.968750
#
# Train Accuracy: 0.976756 Loss: 1076709.950350
#
#
# Validation Accuracy: 0.900884
#
# Epoch: 49
# ========== HYPERNYM PREDICTION ==========
# Steps: 00290 Currernt loss 2252705.919186
# Train Positive Accuracy:  0.9992492492492492
# Train Negative Accuracy:  0.792042042042042
# Train Accuracy:  0.8956456456456456
# ========== IMAGE CLASSIFICATION ==========
# Steps: 05620 Accuracy: 0.984375
# Steps: 05630 Accuracy: 0.960938
# Steps: 05640 Accuracy: 0.984375
# Steps: 05650 Accuracy: 0.972656
# Steps: 05660 Accuracy: 0.988281
# Steps: 05670 Accuracy: 0.980469
# Steps: 05680 Accuracy: 0.976562
# Steps: 05690 Accuracy: 0.968750
# Steps: 05700 Accuracy: 0.992188
# Steps: 05710 Accuracy: 0.976562
# Steps: 05720 Accuracy: 0.972656
# Steps: 05730 Accuracy: 0.972656
#
# Train Accuracy: 0.977526 Loss: 1075432.699430
#
#
# Validation Accuracy: 0.902491

# %%
#Calculate hierarchical recall and precision

index2name = {v:k for k,v in name2index.items()}

ground_truth = []
predicted = []
idxs_order = []

val_errors = []
for batch_idxs in get_batch_idxs(len(X_val), options['batch_size']):
    [val_pred, curr_val_errors] = sess.run(
        [flat_hit_pred, cls_all_errors], feed_dict={ 
            im: X_val[batch_idxs], 
            y: y_val[batch_idxs]
        }
    )

    ground_truth.extend(y_val[batch_idxs])
    predicted.extend(val_pred)

    val_errors.extend(curr_val_errors)

y_val_hier = [hypernyms_per_class[int(l)] for l in ground_truth]

prec = []
recall = []
for idx in range(len(X_val)):
    pred_hier = val_errors[idx] <= min(val_errors[idx][:options['num_base_classes']])
    curr_precision = sum(y_val_hier[idx] * pred_hier) / sum(pred_hier)
    curr_recall = sum(y_val_hier[idx] * pred_hier) / sum(y_val_hier[idx])

    prec.append(curr_precision)
    recall.append(curr_recall)

print("Hierarchial results:\tPrecision: %.2f\tRecall: %.2f" % (np.mean(prec),np.mean(recall)))
# Out:
# Hierarchial results:	Precision: 0.79	Recall: 0.93

# %%
# calculate flat hit accuracy
flat_hit_at_1 = 0
flat_hit_at_3 = 0
flat_hit_at_5 = 0
flat_hit_at_10 = 0

for i in range(len(X_val)):
    try:
        found_idx = list(predicted[i]).index(ground_truth[i])
    except:
        found_idx = 9999999

    if found_idx < 1:
        flat_hit_at_1 += 1.0 / len(X_val)
    if found_idx < 3:
        flat_hit_at_3 += 1.0 / len(X_val)
    if found_idx < 5:
        flat_hit_at_5 += 1.0 / len(X_val)
    if found_idx < 10:
        flat_hit_at_10 += 1.0 / len(X_val)


print("Flat hit accuracy:\t@ 1: %.4f\t@ 3: %.4f\t@ 5: %.4f\t@ 10: %.4f" % (
    flat_hit_at_1,
    flat_hit_at_3,
    flat_hit_at_5,
    flat_hit_at_10
))
# Out:
# Flat hit accuracy:	@ 1: 0.9025	@ 3: 0.9700	@ 5: 0.9834	@ 10: 0.9938
